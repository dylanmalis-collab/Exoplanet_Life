# %%
import pandas as pd
url = "https://raw.githubusercontent.com/dylanmalis-collab/Exoplanet_Life/refs/heads/elt_v2/Exoplanet_DBT/data_exports/raw_exoplanets_enriched.csv"
df = pd.read_csv(url)
# Out:
# C:\Users\berna\AppData\Local\Temp\ipykernel_17996\287856858.py:3: DtypeWarning: Columns (5,100,103,242,350,353,359,362,368,396,399,405,408) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
df.head()
# Out:
#    objectid        pl_name pl_letter    hostid     hostname hd_name hip_name  \
# 0    3.2390  Kepler-1167 b         b  2.136990  Kepler-1167     NaN      NaN
# 1    3.1444  Kepler-1740 b         b  2.433343  Kepler-1740     NaN      NaN
# 2    3.4135  Kepler-1581 b         b  2.442550  Kepler-1581     NaN      NaN
# 3    3.6590   Kepler-644 b         b  2.512738   Kepler-644     NaN      NaN
# 4    3.1575  Kepler-1752 b         b  2.507010  Kepler-1752     NaN      NaN
#
#           tic_id disc_pubdate  disc_year  ... masse_10_24kg  \
# 0  TIC 273875149      2016-05     2016.0  ...     21.320040
# 1  TIC 138479461      2022-02     2021.0  ...     65.692000
# 2  TIC 121215710      2016-05     2016.0  ...      2.609764
# 3  TIC 271669616      2016-05     2016.0  ...     60.317200
# 4  TIC 417655835      2022-02     2021.0  ...    111.676400
#
#   masse_10_24kg_calc Score_roch        pl_type sim_earth eau_possible  \
# 0          21.320040   0.783967  Gazeuse/Mixte  0.196611            0
# 1          65.692000   0.044958  Gazeuse/Mixte  0.278858            0
# 2           2.609764   9.160156       Rocheuse  0.269634            0
# 3          60.317200   0.056949  Gazeuse/Mixte  0.136223            0
# 4         111.676400   0.011750  Gazeuse/Mixte  0.479937            0
#
#   atm_survival_score  atm_ok  pt_habitable               ingestion_timestamp
# 0           0.000979   False             0  2026-04-13 13:33:16.294083+00:00
# 1           0.007785   False             0  2026-04-13 13:33:16.294083+00:00
# 2           0.001450   False             0  2026-04-13 13:33:16.294083+00:00
# 3           0.000427   False             0  2026-04-13 13:33:16.294083+00:00
# 4           0.103682   False             0  2026-04-13 13:33:16.294083+00:00
#
# [5 rows x 704 columns]

# %%
df = df[["pl_name", "hostname", "pl_orbsmax_calc","pl_rade", "pl_bmasse_calc", "pl_dens_calc", "pl_orbeccen", "pl_insol_calc", "pl_eqt_calc","st_spectype_group_en", "st_teff", "st_rad", "st_mass", "st_met", "st_lum_lin_calc", "st_dens", "Gravity_G_earth_calc", "masse_10_24kg_calc","pl_type", "sim_earth", "eau_possible"]]

# %%
df["pl_orbeccen"] = df["pl_orbeccen"].fillna(df["pl_orbeccen"].median())
# Out:
# np.float64(0.0)

# %%
# Out:
# np.int64(0)

# %%
# Out:
# 2128    0.95000
# 4959    0.95000
# 4923    0.94800
# 5655    0.94120
# 1750    0.93183
# Name: pl_orbeccen, dtype: float64

# %%
df["st_teff_missing"] = df["st_teff"].isna().astype(int)

# 1. imputation par groupe
df["st_teff"] = df.groupby("st_spectype_group_en")["st_teff"].transform(
    lambda x: x.fillna(x.median())
)

# 2. fallback global
df["st_teff"] = df["st_teff"].fillna(df["st_teff"].median())

# %%
df["st_mass_missing"] = df["st_mass"].isna().astype(int)

# 1. imputation par groupe
df["st_mass"] = df.groupby("st_spectype_group_en")["st_mass"].transform(
    lambda x: x.fillna(x.median())
)

# 2. fallback global
df["st_mass"] = df["st_mass"].fillna(df["st_mass"].median())

# %%
df["st_rad_missing"] = df["st_rad"].isna().astype(int)

# 1. imputation par groupe
df["st_rad"] = df.groupby("st_spectype_group_en")["st_rad"].transform(
    lambda x: x.fillna(x.median())
)

# 2. fallback global
df["st_rad"] = df["st_rad"].fillna(df["st_rad"].median())

# %%
df["st_met_missing"] = df["st_met"].isna().astype(int)

# 1. imputation par groupe
df["st_met"] = df.groupby("st_spectype_group_en")["st_met"].transform(
    lambda x: x.fillna(x.median())
)

# 2. fallback global
df["st_met"] = df["st_met"].fillna(df["st_met"].median())
# Out:
# d:\Program Files\Python314\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Program Files\Python314\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Program Files\Python314\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
df["st_dens_missing"] = df["st_dens"].isna().astype(int)

# 1. imputation par groupe
df["st_dens"] = df.groupby("st_spectype_group_en")["st_dens"].transform(
    lambda x: x.fillna(x.median())
)

# 2. fallback global
df["st_dens"] = df["st_dens"].fillna(df["st_dens"].median())
df["st_dens"].isna().sum()
# Out:
# d:\Program Files\Python314\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Program Files\Python314\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# np.int64(0)

# %%
df["st_dens"].isna().sum()
# Out:
# np.int64(0)

# %%
#pl_insol + les missing
df2 = df[["pl_orbsmax_calc","pl_rade", "pl_bmasse_calc", "pl_dens_calc", "pl_orbeccen", "st_teff", "st_rad", "st_mass", "st_met", "st_lum_lin_calc", "st_dens", "sim_earth","pl_insol_calc", "st_teff_missing", "st_mass_missing", "st_rad_missing", "st_met_missing"]]

# %%
df2 = df2.dropna(subset=["sim_earth"])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5904 entries, 0 to 6157
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_orbsmax_calc  5904 non-null   float64
#  1   pl_rade          5904 non-null   float64
#  2   pl_bmasse_calc   5904 non-null   float64
#  3   pl_dens_calc     5904 non-null   float64
#  4   pl_orbeccen      5904 non-null   float64
#  5   st_teff          5904 non-null   float64
#  6   st_rad           5904 non-null   float64
#  7   st_mass          5904 non-null   float64
#  8   st_met           5904 non-null   float64
#  9   st_lum_lin_calc  5904 non-null   float64
#  10  st_dens          5904 non-null   float64
#  11  sim_earth        5904 non-null   float64
#  12  pl_insol_calc    5904 non-null   float64
#  13  st_teff_missing  5904 non-null   int64
#  14  st_mass_missing  5904 non-null   int64
#  15  st_rad_missing   5904 non-null   int64
#  16  st_met_missing   5904 non-null   int64
# dtypes: float64(13), int64(4)
# memory usage: 830.2 KB

# %%
#les missing
df = df[["pl_orbsmax_calc","pl_rade", "pl_bmasse_calc", "pl_dens_calc", "pl_orbeccen", "st_teff", "st_rad", "st_mass", "st_met", "st_lum_lin_calc", "st_dens", "sim_earth","st_teff_missing", "st_mass_missing", "st_rad_missing", "st_met_missing"]]

# %%
#pl_insol
df = df[["pl_orbsmax_calc","pl_rade", "pl_bmasse_calc", "pl_dens_calc", "pl_orbeccen", "st_teff", "st_rad", "st_mass", "st_met", "st_lum_lin_calc", "st_dens", "sim_earth","pl_insol_calc"]]

# %%
#Que les valeur physique
df = df[["pl_orbsmax_calc","pl_rade", "pl_bmasse_calc", "pl_dens_calc", "pl_orbeccen", "st_teff", "st_rad", "st_mass", "st_met", "st_lum_lin_calc", "st_dens", "sim_earth"]]
